# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import chardet
import pandas as pd

with open('./Tables/18upr9yfp0514t01.csv', 'rb') as f:
    result = chardet.detect(f.read())

# %%
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df=pd.read_csv('./Tables/18upr9yfp0514t01.csv',encoding='Windows-1252')

# %%
df
# Out:
#                          Bureau of Justice Statistics              Unnamed: 1  \
# 0                      Filename: 18upr9yfp0514t01.csv                     NaN
# 1   Table 1. Characteristics of prisoners released...                     NaN
# 2   Report title: 2018 Update on Prisoner Recidivi...                     NaN
# 3   Data source: Bureau of Justice Statistics, Rec...                     NaN
# 4   Authors: Mariel Alper, Ph.D., and Matthew R. D...                     NaN
# 5   Refer questions to: askbjs@usdoj.gov or 202-30...                     NaN
# 6                          Date of version: 5/23/2018                     NaN
# 7                                                 NaN                     NaN
# 8   Table 1. Characteristics of prisoners released...                     NaN
# 9                                                 NaN                     NaN
# 10                                     Characteristic                     NaN
# ...
