# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
from datetime import date, datetime, timedelta

chromedriver = "/Users/ljborton/Downloads/chromedriver" 
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)

# %%
driver.get("https://www.facebook.com/groups/seattlegirlgeekdinners/members/")

# %% [markdown]
# ### LOGIN TO FACEBOOK

# %%
#scraping
#Need to manually scroll to the bottom of the list of members to get more than the first page
job_xpath = '//*[@id="groupsMemberSection_all_members"]/div[2]'
job= driver.find_element_by_xpath(job_xpath).text

# %%
job
# Out:
# "Message\n3-dots-h\nDeb Dulin\nNew Member\nView 1 recent post\nJoined 3 hours ago\nUMBC\nMessage\n3-dots-h\nAmanda Mitchell\nNew Member\nJoined 3 hours ago\nTutor at Kumon\nMessage\n3-dots-h\nNidhi Singh Pandita\nNew Member\nAdded by Ling Toh Yesterday\nNortheastern University Seattle\nMessage\n3-dots-h\nBeth Roberts\nNew Member\nJoined on Friday\nSeattle, Washington\nMessage\n3-dots-h\nDivya Rathi Maheshwari\nNew Member\nView 1 recent post\nAdded by Pallavi Rukhaiyar on November 10, 2019\nProgram Manager at Microsoft India Development Center, Gachibowli, Hyderabad\nMessage\n3-dots-h\nIrina AndreeaRosoiu\nNew Member\nAdded by Vani Albert on November 10, 2019\nWorks at Microsoft\nMessage\n3-dots-h\nHeather Curtin\nNew Member\nJoined about a week ago\nWorks at Range Kleen Mfg., Inc.\nMessage\n3-dots-h\nAutumn Curtis\nNew Member\nJoined about a week ago\nUniversity of Washington\nMessage\n3-dots-h\nJessica Sills\nNew Member\nJoined about a week ago\nAssociate Engineer at T-Mobile\nMessage\n3-dots-h\nGloria DaPra\nNew Member\nJoined about a week ago\nSeattle, Washington\nMessage\n3-dots-h\nAutumn Capasso\nNew Member\nAdded by Ana Gosseen on November 9, 2019\nUniversity of Maryland Global Campus\nMessage\n3-dots-h\nEmma Oberstein\nNew Member\nJoined about a week ago\nMessage\n3-dots-h\nKimberly Bennett\nNew Member\nJoined about a week ago\nBenefits Manager at Aviation Technical Services\nMessage\n3-dots-h\nAnna Khmelyuk\nNew Member\nJoined about a week ago\nSeattle Central College\nMessage\n3-dots-h\nDeserae Dias\nNew Member\nAdded by Caitlin Cooper on November 9, 2019\nMessage\n3-dots-h\nJamie Pilgrim\nNew Member\nJoined about a week ago\nSoftware Engineer at Avvo\nMessage\n3-dots-h\nDan Yi\nNew Member\nJoined about a week ago\nWuhan University\nMessage\n3-dots-h\nJeanne Edgmand Cost\nNew Member\nJoined about a week ago\nWoodinville, Washington\nMessage\n3-dots-h\nUjwala Kumar\nNew Member\nJoined about a week ago\nAssociate Cybersecurity Engineer at T-Mobile\nMessage\n3-dots-h\nAlexandra Shapira\nNew Member\nJoined about 2 weeks ago\nMessage\n3-dots-h\nMelissa Hoberg\nJoined about 3 weeks ago\nReliability Engineer at Amazon.com\nMessage\n3-dots-h\nReneé Fujii\nAdded by Liz Morgan on October 22, 2019\nWorks at Zume Inc.\nMessage\n3-dots-h\nGulnaz Saitgareeva\nAdded by Olena Rogalska on October 19, 2019\nMessage\n3-dots-h\nUrja Gandhi\nJoined about a month ago\nSr. Software Engineering Manager at Expedia\nMessage\n3-dots-h\nNivedita Patil\nJoined about a month ago\nMessage\n3-dots-h\nSrijani Basak\nJoined about a month ago\nMessage\n3-dots-h\nAshley Cardona\nJoined about a month ago\nProfessional services at Oracle NetSuite\nMessage\n3-dots-h\nDora Li\nJoined about a month ago\nMessage\n3-dots-h\nJenna Myers\nJoined about a month ago\nMonash University\nMessage\n3-dots-h\nYeh-Sun Lee\nAdded by Yeh-Eun Lee on October 10, 2019\nUniversity of Washington\nMessage\n3-dots-h\nShanti Punukollu\nJoined about a month ago\nMessage\n3-dots-h\nSabrina Lowney\nJoined about 2 months ago\nUniversity of Washington\n3-dots-h\nSophie Nop\nAdded by Cate Yochum on October 1, 2019\nMessage\n3-dots-h\nDrashti Bhuta\nAdded by Sneha Salvi on September 30, 2019\nSoftware Development Engineer at OfferUp\nMessage\n3-dots-h\nSonia Jindal\nJoined about 2 months ago\nMessage\n3-dots-h\nEmma Mullen\nAdded by Laura Trutoiu on September 29, 2019\nMessage\n3-dots-h\nManasvini Rao\nJoined about 2 months ago\nUniversity of Michigan\nMessage\n3-dots-h\nMicaela Deitch\nJoined about 2 months ago\nGeorgetown University\nMessage\n3-dots-h\nTiffany Chio\nJoined about 2 months ago\nAustin, Texas\nMessage\n3-dots-h\nStephanie Lake\nJoined about 2 months ago\nMessage\n3-dots-h\nSai Ramtirth\nJoined about 2 months ago\nUniversity of Southern California\nMessage\n3-dots-h\nMarianne Goldin\nJoined about 2 months ago\nMessage\n3-dots-h\nCaitlin Cooper\nJoined about 2 months ago\nMessage\n3-dots-h\nAnya Khlobystina\nJoined about 2 months ago\nMessage\n3-dots-h\nJessica Lane\nJoined ...

# %%
f = open("members_"+ date.today().strftime('%Y_%m_%d') + '.txt', "w")
f.write(job)
f.close()

# %%
driver.close()
